# %%
import pandas as pd
data = pd.read_csv('2500to10500Synthe100000resolution.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'g')
ax.set_xlim(2500,10500)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('2500to10500Synthe100000resolution5750T4g')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('2500to10500res500000.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(2500,10500)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('2500to10500_5750T4gres500000')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('2500to10500res500000HD.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(2500,10500)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('2500to10500_5750T4gres500000HD')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-54d54cd71965> in <module>
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('2500to10500res500000HD.txt', sep='\s+', header=None)
#       3 data = pd.DataFrame(data)
#       4 import matplotlib.pyplot as plt
#       5 x = data[0]
#
# ...

# %%
import pandas as pd

data = pd.read_csv('f2500-10500vr0p00t5750g35k2c05_1al_H_0.5.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'g')

ax.set_xlim(2500,2800)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('2500-10500vr0p00t5750g35k2c05and_l/H-5')


plt.show()

# %%
import pandas as pd
data = pd.read_csv('2500to10500res500000withnorgfalllines.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(2500,10500)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('2500to10500res500000withnorgfalllines')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('2500to10500res500000withonlyrmmoecasc.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(2500,10500)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('2500to10500res500000withonlyrmmoecasc')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('2500to10500res500000cutoff0pt1.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(2500,10500)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('2500to10500res500000cutoff0pt1')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('2500to10500res500000cutoff0pt00001.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(2500,10500)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('2500to10500res500000cutoff0pt00001')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('7000-7210Synthet4970g46.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'g')

ax.set_xlim(6990,7220)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('continuum flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('7000-7210Synthet4970g46resol500000')

plt.savefig('7000-7210Synthet4970g46')

plt.show()

# %%
import pandas as pd

data = pd.read_csv('7000-7210Synthet4970g46resolution100000.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'g')

ax.set_xlim(7000,7210)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('7000-7210Synthet4970g46resolution100000')


plt.show()

# %%
import pandas as pd

data = pd.read_csv('7000-7210Synthet4476g12.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'g')

ax.set_xlim(7000,7210)

ax.set_ylim(640000,680000)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('7000-7210Synthet4476g12resolution500000')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('7000-7210Synthet4970g46allrmolecscfiles.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'g')

ax.set_xlim(7000,7210)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('7000-7210Synthet4970g46allrmolecscfiles')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('3000-10000Synthet4476g12.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'r')

ax.set_xlim(3000,3500)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('3000-10000Synthet4476g12resolution600000')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('3000-10000Synthet4476g12forCNNHCH.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'g')

ax.set_xlim(3000,10000)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('3000-10000Synthet4476g12resolution500000forCNNHCHfilesalone')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('CNONa1__2500-10500Synthet4476g12.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'r')

ax.set_xlim(3000,10500)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('CNONa1__2500-10500Synthet4476g12')
plt.savefig('CNONa1__2500-10500Synthet4476g12')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('CNONa1__2500-10500Synthet4476g12and100000gaussian1700.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'r')

ax.set_xlim(3500,10000)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('CNONa1__2500-10500Synthet4476g12and100000gaussian1700')
plt.savefig('CNONa1__2500-10500Synthet4476g12and100000gaussian1700')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('CNONa1__3000-10000Synthet4476g12and100000.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'r')

ax.set_xlim(3000,10000)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('CNONa1__4476g12and100000')
plt.savefig('CNONa1__4476g12and100000gaussian48000')
plt.show()

# %%
import pandas as pd

data = pd.read_csv('CNONa1__2500-10500Synthet4476g12and100000gaussian48000.txt', sep='\s+', header=None)

data = pd.DataFrame(data)

import matplotlib.pyplot as plt

x = data[0]

y = data[1]

fig, ax = plt.subplots()

ax.plot(x,y,'r')

ax.set_xlim(3000,10000)

ax.set_xlabel('Wavelength in Armstrong')

ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)

plt.title('CNONa1__2500-10500Synthet4476g12and100000gaussian48000')
plt.savefig('CNONa1__2500-10500Synthet4476g12and100000gaussian48000')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('7000-7210Synthet4970g46resolution6000000.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(7000,7210)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('7000-7210Synthet4970g46resolution6000000')
plt.savefig('7000-7210Synthet4970g46resolution6000000')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('7000-7210Synthet4970g46resolution60000.txt', sep='\s+', header=None)
data = pd.DataFrame(data)
import matplotlib.pyplot as plt
x = data[0]
y = data[1]
fig, ax = plt.subplots()

ax.plot(x,y,'r')
ax.set_xlim(7000,7210)
ax.set_xlabel('Wavelength in Armstrong')
ax.set_ylabel('flux in erg/sec/cm2/Angstrong')

ax.grid(True)
plt.title('7000-7210Synthet4970g46resolution60000')
plt.savefig('7000-7210Synthet4970g46resolution60000')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy import units as u
from specutils.spectra import Spectrum1D, SpectralRegion
from specutils.fitting import fit_generic_continuum
from specutils.fitting import fit_continuum

# %%
data = np.loadtxt('CNONa1__2500-10500Synthet4476g12.txt')
x = data[:, 0]
y = data[:, 1]

# %%
x1=x[0:-1]
y1=y[0:-1]
plt.plot(x1, y1, 'r') 
plt.title('spectra')
plt.grid(True)
plt.show()

# %%
x1[2501]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-142-1e416ef49a44> in <module>
# ----> 1 x1[2501]
#
# IndexError: index 2501 is out of bounds for axis 0 with size 2501

# %%
flux=y1*(u.erg / (u.cm ** 2 * u.s * u.AA))
spectral_axis = x1*u.AA

# %%
spectrum = Spectrum1D(flux, spectral_axis)
region = [(2500.*u.AA,2600.*u.AA),(2600.*u.AA,2700.*u.AA),(2700.*u.AA,2800.*u.AA),(2800.*u.AA,2900.*u.AA),(2900.*u.AA,3000.*u.AA),(3000.*u.AA,3100.*u.AA),(3100.*u.AA,3200.*u.AA),(3200.*u.AA,3300.*u.AA),(3300.*u.AA,3400.*u.AA),(3400.*u.AA,3500.*u.AA),(3500.*u.AA,3600.*u.AA),(3600.*u.AA,3700.*u.AA),(3700.*u.AA,3800.*u.AA),(3800.*u.AA,3900.*u.AA),(3900.*u.AA,4000.*u.AA),(4000.*u.AA,4100.*u.AA),(4100.*u.AA,4200.*u.AA),(4200.*u.AA,4300.*u.AA),(4300.*u.AA,4400.*u.AA),(4400.*u.AA,4500.*u.AA),(4500.*u.AA,4600.*u.AA),(4600.*u.AA,4700.*u.AA),(4700.*u.AA,4800.*u.AA),(4800.*u.AA,4900.*u.AA),(4900.*u.AA,5000.*u.AA),(5000.*u.AA,5100.*u.AA),(5100.*u.AA,5200.*u.AA),(5200.*u.AA,5300.*u.AA),(5300.*u.AA,5400.*u.AA),(5400.*u.AA,5500.*u.AA),(5500.*u.AA,5600.*u.AA),(5600.*u.AA,5700.*u.AA),(5700.*u.AA,5800.*u.AA),(5800.*u.AA,5900.*u.AA),(5900.*u.AA,6000.*u.AA),(6000.*u.AA,6100.*u.AA),(6100.*u.AA,6200.*u.AA),(6200.*u.AA,6300.*u.AA),(6300.*u.AA,6400.*u.AA),(6400.*u.AA,6500.*u.AA),(6500.*u.AA,6600.*u.AA),(6600.*u.AA,6700.*u.AA),(6700.*u.AA,6800.*u.AA),(6800.*u.AA,6900.*u.AA),(6900.*u.AA,7000.*u.AA),(7000.*u.AA,7100.*u.AA),(7100.*u.AA,7200.*u.AA),(7200.*u.AA,7300.*u.AA),(7300.*u.AA,7400.*u.AA),(7400.*u.AA,7500.*u.AA),(7500.*u.AA,7600.*u.AA),(7600.*u.AA,7700.*u.AA),(7700.*u.AA,7800.*u.AA),(7800.*u.AA,7900.*u.AA),(7900.*u.AA,8000.*u.AA),(8000.*u.AA,8100.*u.AA),(8100.*u.AA,8200.*u.AA),(8200.*u.AA,8300.*u.AA),(8300.*u.AA,8400.*u.AA),(8400.*u.AA,8500.*u.AA),(8500.*u.AA,8600.*u.AA),(8600.*u.AA,8700.*u.AA),(8700.*u.AA,8800.*u.AA),(8800.*u.AA,8900.*u.AA),(8900.*u.AA,9000.*u.AA),(9000.*u.AA,9100.*u.AA),(9100.*u.AA,9200.*u.AA),(9200.*u.AA,9300.*u.AA),(9300.*u.AA,9400.*u.AA),(9400.*u.AA,9500.*u.AA),(9500.*u.AA,9600.*u.AA),(9600.*u.AA,9700.*u.AA),(9700.*u.AA,9800.*u.AA),(9800.*u.AA,9900.*u.AA),(9900.*u.AA,10000.*u.AA),(10000.*u.AA,10100.*u.AA),(10100.*u.AA,10200.*u.AA),(10200.*u.AA,10300.*u.AA),(10300.*u.AA,10400.*u.AA),(10400.*u.AA,10500.*u.AA)]

# %%
fitted_continuum=fit_continuum(spectrum, window=region)
y_continuum_fitted = fitted_continuum(x1*u.AA)
plt.plot(x1, y_continuum_fitted,'k')
plt.plot(spectrum.spectral_axis, spectrum.flux) 
plt.title('Continuum Fitting')
plt.grid(True)
plt.show()
# Out:
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# WARNING:astropy:Model is linear in parameters; consider using linear fitting methods.

# %%
spec_normalized = spectrum / y_continuum_fitted

plt.plot(spec_normalized.spectral_axis, spec_normalized.flux)
plt.title('Continuum normalized spectrum')
plt.grid('on')

# %%
from specutils.spectra import Spectrum1D, SpectralRegion
from specutils.fitting import fit_generic_continuum

g1_fit = fit_generic_continuum(spectrum)

y_continuum_fitted = g1_fit(x1*u.AA)

plt.plot(x1, y1,'r')
plt.plot(x1, y_continuum_fitted)
plt.title('Continuum Fitting')
plt.grid(True)
# Out:
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# WARNING:astropy:Model is linear in parameters; consider using linear fitting methods.

# %%
spec_normalized = spectrum / y_continuum_fitted

plt.plot(spec_normalized.spectral_axis, spec_normalized.flux)
plt.title('Continuum normalized spectrum')
plt.grid('on')
plt.savefig('Continuum_fitted_CNONa')
plt.show()

# %%
from specutils.manipulation import noise_region_uncertainty
noise_region = SpectralRegion(0*u.AA, 3*u.AA)
spectrum = noise_region_uncertainty(spectrum, noise_region)

# %%
from specutils.fitting import find_lines_threshold

# %%
lines = find_lines_threshold(spectrum, noise_factor=3)
# Out:
# WARNING: Spectrum is not below the threshold signal-to-noise 0.01. This may indicate you have not continuum subtracted this spectrum (or that you have but it has high SNR features).
#
# If you want to suppress this warning either type 'specutils.conf.do_continuum_function_check = False' or see http://docs.astropy.org/en/stable/config/#adding-new-configuration-items for other ways to configure the warning. [specutils.analysis.flux]
# WARNING:astropy:Spectrum is not below the threshold signal-to-noise 0.01. This may indicate you have not continuum subtracted this spectrum (or that you have but it has high SNR features).
#
# If you want to suppress this warning either type 'specutils.conf.do_continuum_function_check = False' or see http://docs.astropy.org/en/stable/config/#adding-new-configuration-items for other ways to configure the warning.
# /home/ram/snap/jupyter/common/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in greater
# ...

# %%
lines[lines['line_type'] == 'emission']
# Out:
# /home/ram/snap/jupyter/common/lib/python3.7/site-packages/astropy/table/column.py:1152: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(super(), op)(other)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-beac380d7403> in <module>
# ----> 1 lines[lines['line_type'] == 'emission']
#
# /home/ram/snap/jupyter/common/lib/python3.7/site-packages/astropy/table/table.py in __getitem__(self, item)
#    1640             return self.columns[item]
#    1641         elif isinstance(item, (int, np.integer)):
# -> 1642             return self.Row(self, item)
#    1643         elif (isinstance(item, np.ndarray) and item.shape == () and item.dtype.kind == 'i'):
#    1644             return self.Row(self, item.item())
#
# ...

# %%
g_init = models.Gaussian1D(amplitude=3.*u.Jy, mean=6.1*u.um, stddev=1.*u.um)
g_fit = fit_lines(spectrum, g_init)
y_fit = g_fit(x*u.um)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-d145902c9e4a> in <module>
# ----> 1 g_init = models.Gaussian1D(amplitude=3.*u.Jy, mean=6.1*u.um, stddev=1.*u.um)
#       2 g_fit = fit_lines(spectrum, g_init)
#       3 y_fit = g_fit(x*u.um)
#
# NameError: name 'models' is not defined
