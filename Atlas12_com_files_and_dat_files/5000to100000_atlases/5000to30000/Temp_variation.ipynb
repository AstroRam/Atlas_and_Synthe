# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,0]
    Y=data[:,1]
    plt.plot(X,Y,marker='.')
#plt.xlim(0,6)
#plt.ylim(0,100000)
plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Temperatue v/s Mass depth variable')
plt.xlabel('Mass depth variable_RHOX (g/cm^2)')
plt.ylabel('Temperature(K)')
plt.savefig('Temp_vs_Rhox.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,0]
    Y=data[:,2]
    plt.plot(X,Y,marker='.')
#plt.xlim(0,6)
#plt.ylim(0,240000)

plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Pressure v/s Mass depth variable')
plt.xlabel('Mass depth variable_RHOX (g/cm^2)')
plt.ylabel('Pressure in dyn/cm^2')
plt.savefig('Pressure_vs_Rhox.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,1]
    Y=data[:,2]
    plt.plot(X,Y,marker='.')
plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Pressure v/s Temperature')
plt.xlabel('Temperature in K')
plt.ylabel('Pressure in dyn/cm^2')
plt.savefig('PressurevsTemperature.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,1]
    Y=data[:,3]
    plt.plot(X,Y,marker='.')

plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Electron Density v/s Temperature')
plt.xlabel('Temperature(K)')
plt.ylabel('Electron Density in cm^-3')
plt.savefig('Electron Density_vs_Temperature.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,1]
    Y=data[:,4]
    plt.plot(X,Y,marker='.')

plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Rosseland absorption coefficient v/s Temperature')
plt.xlabel('Temperature(K)')
plt.ylabel('Rosseland absorption coefficient(cm^2/g)')
plt.savefig('Rosseland_absorption_coeff_vs_Temperature.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,0]
    Y=data[:,4]
    plt.plot(X,Y,marker='.')
#plt.xlim(0,1.5)
plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Rosseland absorption coefficient v/s Mass density variable')
plt.xlabel('mass density variable RHOX')
plt.ylabel('Rosseland absorption coefficient(cm^2/g)')
plt.savefig('Rosseland_absorption_coeff_vs_RHOX.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,1]
    Y=data[:,5]
    plt.plot(X,Y,marker='.')

plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Pressure due to radiation v/s Temperature')
plt.xlabel('Temperature(K)')
plt.ylabel('Pressure due to radiation (dyn/s^2 )')
plt.savefig('Radiative pressure_vs_Temperature.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')

# %%
import numpy as np
import matplotlib.pyplot as plt

for fname in ('ap00t5000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t8000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t10000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t12000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t15000g44377k1odfnew_solar_scaled_mod_60iter.dat', 'ap00t20000g44377k1odfnew_solar_scaled_mod_60iter.dat','ap00t30000g44377k1odfnew_solar_scaled_mod_60iter.dat'):
    data=np.loadtxt(fname)
    X=data[:,0]
    Y=data[:,5]
    plt.plot(X,Y,marker='.')
#plt.xlim(0,6)    
plt.legend(["5000", "8000", "10000","12000", "15000", "20000", "30000"])
plt.title('Radiative pressure v/s Mass depth variable_RHOX')
plt.xlabel('Mass depth variable_RHOX (g/cm^2)')
plt.ylabel('Pressure due to radiation (dyn/s^2 )')
plt.savefig('Radiative pressure_vs_Mass depth variable_RHOX.png',dpi=720,transparent=False,bbox_inches='tight',facecolor='w', edgecolor='w')
